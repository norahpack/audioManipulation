# %%
# CS5 Gold, Lab 3
# Filename: hw3pr1.py
# Name: Norah Pack
# Problem description: Lab 3 problem, "Sounds Good!"

# %%
# first, let's make sure that sound works for this notebook...  
# (Keep everything in the hw3pr1 folder.)
#

# %%
#
# libraries to import   (may take several seconds the first time you run this cell...)
#
from csaudio import *
import time
import random
import math
import wave
wave.big_endian = 0

# %%
# our in-browser test function to make sure everything is working
#
def test():
    """A test function that plays swfaith.wav
       You'll need swfaith.wav in this folder. 
    """
    return play('swfaith.wav')   # try - or don't try - swnotry.wav (or spam.wav)

test()

# %%
#
# _if_ the above test() function does not work, then try this one,
#
#    which uses altplay( filename ) 
#
#    without creating a browser "widget" (it just plays)
#

# our alternative test function -- if this works, use altplay instead of play later on...
def alttest():
    """A test function that plays swfaith.wav
       You'll need swfaith.wav in this folder.
    """
    return altplay('swfaith.wav')

alttest()


# IF alttest() worked, but test() did not, then uncomment this line below:

# play = altplay    # this will define play to be altplay (if only altplay workd)

# then re-run this cell. The function play will then be altplay.

# %%
# Ok!   First, some reminders about list comprehensions:

# %%
# a function to get started with a reminder
# about list comprehensions...
def three_ize(L):
    """three_ize is the motto of the green CS 5 alien.
       It's also a function that accepts a list and
       returns a list of elements, each three times as large.
    """
    # this is an example of a list comprehension
    LC = [3 * x for x in L]
    return LC

# %%
#
# Function to write #1:  scale
#
def scale(L, scale_factor):
    """
    this function returns a list that is every element in the list L multiplied by scale_factor.
    L is a list
    scale_factor is a floating point number.
    """
    LC=[scale_factor*x for x in L]
    return LC
#scale([1,2,3], 2)
# Out:
# [2, 4, 6]

# %%
# here is an example of a different method
# for writing the three_ize function:
def three_ize_by_index(L):
    """three_ize_by_index has the same behavior as three_ize
       but it uses the INDEX of each element, instead of
       using the elements themselves -- this is much more flexible!
    """
    # we get the length of L first, in order to use it in range:
    N = len(L)
    LC = [3 * L[i] for i in range(N)]
    return LC
three_ize_by_index([1,2,3])
# Out:
# [3, 6, 9]

# %%
#
# Function to write #2:  add_2
#
def add_2(L, M):
    """
    L and M are lists.
    add_2 returns a single list that is an element-by-element sum of the two arguments, whose length is the same as the shorter of the two input lists.
    """
    N=min(len(L), len(M))
    LC=[L[i]+M[i] for i in range(N)]
    return LC
#add_2([1,2,3,4,5], [3,4,6])
# Out:
# [4, 6, 9]

# %%
#
# Function to write #3:  add_3
#
def add_3(L, M, N):
    """
    L M and N are lists.
    add_3 returns a single list that is an element-by-element sum of the three arguments, whose length is the same as the shortest of the three input lists.
    """
    Q=min(len(L), len(M), len(N))
    LC=[L[i]+M[i]+N[i] for i in range(Q)]
    return LC
#add_3([1,2,3,4,5], [6,7,9], [1,5,6])
# Out:
# [8, 14, 18]

# %%
#
# Function to write #4:  add_scale_2
#

def add_scale_2(L, M, L_scale, M_scale):
    """
    L and M are lists
    L_scale and M_scale are floating point numbers
    add_scale_2 returns a single list that is an element-by-element sum of the two argument lists, each scaled by a factor of L_scale or M_scale, respectively. The length of the returned list is the same as the shorter of the two input lists.
    """
    Q=min(len(L), len(M))
    LC=[L_scale*L[i]+M_scale*M[i] for i in range(Q)]
    return LC
#add_scale_2([1,2,3], [2,3], 2, 1)
# Out:
# [4, 7]

# %%
# Helper function:  randomize

def randomize(x, chance_of_replacing):
    """randomize accepts an original value, x
       and a fraction named chance_of_replacing.

       With a "chance_of_replacing" chance, it
       should return a random float from -32768 to 32767.

       Otherwise, it should return x (not replacing it).
    """
    r = random.uniform(0, 1)
    if r < chance_of_replacing:
        return random.uniform(-32768, 32767)
    else:
        return x
    
# let's see it in action!  Once:
print("One time: ", randomize(42, 0.5))
print()

# ten times:
LC = [randomize(42, 0.5) for i in range(10)]
print("An LC of ten:\n", LC)
# Out:
# One time:  42
#
# An LC of ten:
#  [42, 42, 42, -19174.736026771738, -133.67164883813166, -8477.14856205482, 42, 29101.399031819055, -19038.15528218976, 42]

# %%
#
# Function to write #5:  replace_some
#
def replace_some(L, chance_of_replacing):
    """
    L is a list
    chance_of_replacing is a floating point value [between 0 and 1]
    replace_some either replaces or does not replace each value in L using the helper function randomize
    """
    LC=[randomize(x, chance_of_replacing) for x in L]
    return LC
#replace_some([1,2,3,4,5],0.5)
# Out:
# [1, 10148.478864521647, 3, -7602.418599475037, 5]

# %%
#
# below are functions that relate to sound-processing ...
#

# %%
# [[ repeat from above ]]
# Our in-browser test function to make sure everything is working
def test():
    """A test function that plays swfaith.wav
       You'll need swfaith.wav in this folder.
    """
    return play('swfaith.wav')

test()

# if this test() doesn't work, run the "alttest()" cell near the top...
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#
# Our first example: the changeSpeed function
#
def changeSpeed(filename, newsr):
    """changeSpeed allows the user to change an audio file's speed.
       Arguments: filename, the name of the original file
                  newsr, the new sampling rate in samples per second
       Result: creates the sound file 'out.wav'
               and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)        # Opens the file and returns two things:
    # samps, a list of the raw pressure samples
    # sr, an inteter which is the sampling rate (number of samples per second)
    # sr is usually 22050  (22050 samples per second)

    N = len(samps)                        # samps is a LIST of the raw pressure samples, N is the # of samples
    print("The first 10 sound-pressure samples are\n", samps[:10])
    print("Total number of samples in the list samps ==", N)
    print("The sampling rate is sr ==", sr, "samples per second")

    # here, we create a new sound, both a new list of samples and a new sampling rate (ok to be unchanged):
    
    newsamps = samps                      # The new list of samples is set to the old list of samples
                                          # later we will change samps into newsamps
    newsr = newsr                         # The new sampling rate, newsr, is passed in to write_wav
                                          # The above line really isn't needed, but it's a nice scaffold
        
    # here, we write out the newsamps and newsr, as a list [newsamps, newsr]
    write_wav([newsamps, newsr], "out.wav")  # writes data to a new file, out.wav
    
    print("\nPlaying new sound...")
    return play('out.wav')                # play the newly created file, 'out.wav'

# %%
# let's try it!
changeSpeed("swfaith.wav", 44100)         # 22050 is "normal";  11025 is fun!
# Out:
# Reading in the sound data...
# The first 10 sound-pressure samples are
#  [7086.0, 7848.0, 8268.0, 9201.0, 9903.0, 10408.0, 11022.0, 11442.0, 11716.0, 11830.0]
# Total number of samples in the list samps == 52338
# The sampling rate is sr == 22050 samples per second
#
# Playing new sound...
# You opened swfaith.wav which has
#     52338 audio samples, taken at
#     22050 hertz (samples per second).
#
#
# You have written the file out.wav which has
#     52338 audio samples, taken at
#     44100 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#
# our second example, the flipflop function
#
def flipflop(filename):
    """flipflop swaps the halves of an audio file
       Argument: filename, the name of the original file
       Result: no return value, but
               this creates the sound file 'out.wav'
               and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)

    print("Computing new sound...")
    # this gets the midpoint and calls it m
    m = len(samps) // 2
    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = samps[m:] + samps[:m]   # side note: we could have used flipside!
    newsr = sr                         # the new sampling rate, newsr, is set to be the old rate, sr

    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')

# %%
# let's try it!
flipflop("swnotry.wav")
# Out:
# Reading in the sound data...
# Computing new sound...
# Writing out the new sound data...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
# Playing new sound...
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #1:  reverse    (copy flipflop, above, as a guide!)

def reverse(filename):
    """reverse takes an audio file and creates a new sound file that is the input audio file backwards
    Argument: filename, the name of the original file
    Result: no return value, but
    this creates the sound file 'out.wav'
    and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)

    print("Computing new sound...")
    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = samps[::-1]   # side note: we could have used flipside!
    newsr = sr                         # the new sampling rate, newsr, is set to be the old rate, sr

    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')
#reverse("swnotry.wav")
# Out:
# Reading in the sound data...
# Computing new sound...
# Writing out the new sound data...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
# Playing new sound...
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #2:  volume      (again, use prior examples as guides!)

def volume(filename, scale_factor):
    """volume takes an audio file and creates a new sound file that is the input audio file but the volume is scaled by scale_factor
    Argument: filename, the name of the original file, scale_factor, a floating point that is the factor to scale the volume by.
    Result: no return value, but
    this creates the sound file 'out.wav'
    and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)

    print("Computing new sound...")
    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = scale(samps, scale_factor)                    
    newsr=sr
    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')
#volume('swnotry.wav', 0.25)
# Out:
# Reading in the sound data...
# Computing new sound...
# Writing out the new sound data...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
#
#
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
# Playing new sound...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #3:  static

def static(filename, probability_of_static):
    """static takes an audio file and creates a new sound file that is the input audio file but the output samples are replaced by static with a probability that is equal to probability_of_static 
    Argument: filename, the name of the original file, probability_of_static, a floating point between 0 and 1
    Result: no return value, but
    this creates the sound file 'out.wav'
    and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)

    print("Computing new sound...")

    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = replace_some(samps, probability_of_static)                    
    newsr=sr
    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')
static('swnotry.wav', 0.05)
# Out:
# Reading in the sound data...
# Computing new sound...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
# Writing out the new sound data...
# Playing new sound...
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #4:  overlay

def overlay(filename1, filename2):
    """overlay takes two audio files and creates a new sound file that is the two input audio files overlayed on one another. 
    Argument: filename1, the name of the first original file, filename 2, the name of the second original file
    Result: no return value, but
    this creates the sound file 'out.wav'
    and plays it
    """
    print("Reading in the sound data...")
    samps1, sr1 = read_wav(filename1)
    samps2, sr2 = read_wav(filename2)
    difference=abs(len(samps1)-len(samps2))

    if(len(samps1)<len(samps2)):
        which_file=filename1
        newestsamps=samps1[:]+samps1[:difference]
        write_wav([newestsamps, sr1], "lengthsame.wav")
        samps1, sr1=read_wav("lengthsame.wav")
    else:
        which_file=filename2
        newestsamps=samps2[:]+samps2[:difference]

        write_wav([newestsamps, sr1], "lengthsame.wav")
        samps2, sr2=read_wav("lengthsame.wav")
    
    
        

    print("Computing new sound...")

    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = add_scale_2(samps1, samps2, 0.75, 0.5)                    
    newsr=sr1
    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')
overlay('swnotry.wav', 'swfaith.wav')
# Out:
# Reading in the sound data...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
#
#
# You opened swfaith.wav which has
#     52338 audio samples, taken at
#     22050 hertz (samples per second).
# 52338
# 47476
# You have written the file lengthsame.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#
#
# You opened lengthsame.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
# samps 2 = 99814
# Computing new sound...
# Writing out the new sound data...
# Playing new sound...
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #5:  echo

def echo(filename, time_delay):
    """echo creates a sound file that is the original sound file plus the sound file overlayed again after a delay of time_delay_seconds.
       Argument: filename, the name of the original file
       time_delay: a floating-point value, number of seconds
       Result: no return value, but
               this creates the sound file 'out.wav'
               and plays it
    """
    print("Reading in the sound data...")
    samps, sr = read_wav(filename)

    print("Computing new sound...")
    num_samps=int(sr*time_delay)
    new_samps=[0 for i in range(num_samps)]+samps
    write_wav([ new_samps, sr], "delay.wav")
    
    # here, we create a new sound, both a new list of samples and a new sampling rate:
    newsamps = add_scale_2(samps, new_samps, 0.75, 0.5)   # side note: we could have used flipside!
    newsr = sr                         # the new sampling rate, newsr, is set to be the old rate, sr

      
    print("Writing out the new sound data...")
    write_wav([newsamps, newsr], "out.wav")  # need to write a data-pair of [list-of-samps,s.rate]

    print("Playing new sound...")
    return play('out.wav')
    
echo("swnotry.wav", 0.5)
# Out:
# Reading in the sound data...
# Computing new sound...
# You opened swnotry.wav which has
#     99814 audio samples, taken at
#     22050 hertz (samples per second).
#
#
# You have written the file delay.wav which has
#     110839 audio samples, taken at
#     22050 hertz.
# Writing out the new sound data...
# Playing new sound...
# You have written the file out.wav which has
#     99814 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Helper function for generating pure tones
def gen_pure_tone(freq, seconds):
    """gen_pure_tone returns the y-values of a cosine wave
       whose frequency is freq Hertz.
       It returns nsamples values, taken once every 1/22050 of a second.
       Thus, the sampling rate is 22050 hertz.
       0.5 second (11025 samples) is probably enough for testing.
    """
    data_pair = [0, 0]                    # Initialize the data here
    sampling_rate = 22050                 # number of data samples per second
    nsamples = int(seconds*sampling_rate) # Rounds down
    f = freq*2*math.pi/sampling_rate      # f converts from samples to Hz -- with radians
    amp = 32767.0                         # our amplitude coefficient, amp
    
    newsamps = [amp*math.sin(f*n) for n in range(nsamples)]  # new samples
    newsr = sampling_rate                                    # new sampling_rate
    
    data_pair[0] = newsamps
    data_pair[1] = newsr
    return data_pair    # this is the data-pair that write_wav needs...

# better not to call gen_pure_tone on its own... we'll use it in the function below:

# %%
def pure_tone(freq, time_in_seconds):
    """Generates and plays a pure tone of the given frequency."""
    print("Generating tone...")
    samps, sr = gen_pure_tone(freq, time_in_seconds)

    print("Writing out the sound data...")
    write_wav([samps, sr], "out.wav") # write data to out.wav

    print("Playing new sound...")
    return play('out.wav')

pure_tone(440, 1.0)                   # 440 hz "concert A" for one second 
                                      # (the sampling rate will be 22050)
# Out:
# Generating tone...
# Writing out the sound data...
# Playing new sound...
# You have written the file out.wav which has
#     22050 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Sound function to write #6:  chord    (copy pure_tone as a starting point)

def add_scale_3(L, M, N, L_scale, M_scale, N_scale):
    """
    L and M and N are lists
    L_scale and M_scale and N_scale are floating point numbers
    add_scale_3 returns a single list that is an element-by-element sum of the three argument lists, each scaled by a factor of L_scale or M_scale or N_scale, respectively. The length of the returned list is the same as the shorter of the three input lists.
    """
    Q=min(len(L), len(M), len(N))
    LC=[L_scale*L[i]+M_scale*M[i] +N_scale*N[i] for i in range(Q)]
    return LC

def chord(f1, f2, f3, time_in_seconds):
    """f1, f2, and f3 are floating point frequencies
    time_in_seconds is a floating point time in seconds of how long the tones should be.
    generates a chord of 3 pure tones.
    """
    print("Generating tone...")
    samps1, sr1 = gen_pure_tone(f1, time_in_seconds)
    samps2, sr2 = gen_pure_tone(f2, time_in_seconds)
    samps3, sr3 = gen_pure_tone(f3, time_in_seconds)
    
    print("Writing out the sound data...")
    new_samps=add_scale_3(samps1, samps2, samps3, 0.33, 0.33, 0.33)
    
    write_wav([new_samps, sr1], "out.wav") # write data to out.wav

    print("Playing new sound...")
    return play('out.wav')

chord(440.000, 523.251, 659.255, 1.0)
# Out:
# Generating tone...
# Writing out the sound data...
# Playing new sound...
# You have written the file out.wav which has
#     22050 audio samples, taken at
#     22050 hertz.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#
# Congratulations! 
#
# Submit lab3 to the usual place...      (as hw3pr1.ipynb, if possible)
#
# and, feel free to play around with audio data in Python!    
#
# (Audacity is a nice converter to/from the wav format, with Mudd author D. Mazzoni :-)
#
